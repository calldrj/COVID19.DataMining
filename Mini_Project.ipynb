# %% [markdown]
# <a href="https://colab.research.google.com/github/calldrj/COVID19.DataMining/blob/master/Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Import Libraries, Load and Inspect Datasets**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

df_train = pd.read_csv('survey/dataset_psycology_survey.csv')
df_pred_ = pd.read_csv('survey/submission_psycology_survey.csv')
print('Pandas done reading.')
# Out:
# Pandas done reading.
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
print('Training dataset has {} rows and {} columns'.format(df_train.shape[0], df_train.shape[1]))
print('\n' + '* ' * 40)
print(df_train.head())
# Out:
# Training dataset has 970 rows and 150 columns
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#    Music  Slow songs or fast songs  ...  Village - town  House - block of flats
# 0    5.0                       3.0  ...         village          block of flats
# 1    4.0                       4.0  ...            city          block of flats
# 2    5.0                       5.0  ...            city          block of flats
# 3    5.0                       3.0  ...            city                   house
# 4    5.0                       3.0  ...         village          house/bungalow
#
# [5 rows x 150 columns]

# %%
print('Prediction dataset has {} rows and {} columns'.format(df_pred_.shape[0], df_pred_.shape[1]))
print('\n' + '* ' * 40)
df_pred_.head()
# Out:
# Prediction dataset has 40 rows and 150 columns
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#    Unnamed: 0  Music  ...  Village - town  House - block of flats
# 0           0    5.0  ...            city          block of flats
# 1           1    5.0  ...         village          house/bungalow
# 2           2    5.0  ...            city          block of flats
# 3           3    5.0  ...            city          house/bungalow
# 4           4    5.0  ...         village                   house
#
# [5 rows x 150 columns]

# %% [markdown]
# ### **Find Mismatched Columns Between Datasets**

# %%
train_pred = [x for x in df_train.columns if x not in df_pred_.columns]
pred_train = [x for x in df_pred_.columns if x not in df_train.columns]
print(train_pred)
print(pred_train)
# Out:
# ['Spending on healthy eating']
# ['Unnamed: 0']

# %% [markdown]
# # **2. Perform EDA for Datasets**
# > ### **2.1. Select Features and Change Columns Names**

# %%
new_names = {'Healthy eating':    'Lifestyle',
             'Spending on looks': 'Look',
             'Eating to survive': 'Taste'}

df_train.rename(columns={'Spending on healthy eating': 'Spend'}, inplace=True)
df_train.rename(columns=new_names, inplace=True)
df_pred_.rename(columns=new_names, inplace=True)

main_idx = [75, 93, 101, 137, 141, 142, 95, 140, 144, 146]
features = [df_train.columns.tolist()[k] for k in main_idx]
# Slice the prediction datamframe be selected features
df_pred_= df_pred_[features]

# Add target in features to slice the training dataframe
features.append('Spend')
df_train = df_train[features]

print(df_train.sample(10))
print('\n' + '* ' * 30)
print(df_pred_.sample(10))
# Out:
#      Lifestyle  Hypochondria  Health  ...  Gender                Education  Spend
# 141        3.0           1.0     4.0  ...    male         secondary school    4.0
# 693        1.0           1.0     4.0  ...    male         secondary school    5.0
# 578        3.0           1.0     2.0  ...  female         secondary school    3.0
# 681        2.0           1.0     4.0  ...  female  college/bachelor degree    3.0
# 308        NaN           1.0     4.0  ...    male         secondary school    5.0
# 774        1.0           3.0     2.0  ...    male  college/bachelor degree    3.0
# 435        5.0           1.0     4.0  ...    male  college/bachelor degree    4.0
# 352        4.0           4.0     4.0  ...  female  college/bachelor degree    4.0
# 739        3.0           2.0     3.0  ...  female         secondary school    2.0
# 349        1.0           1.0     3.0  ...  female        secondary schools    4.0
#
# [10 rows x 11 columns]
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#     Lifestyle  Hypochondria  Health  ...   Age  Gender                Education
# 31        3.0           4.0     2.0  ...  22.0  female  college/bachelor degree
# 3         2.0           3.0     3.0  ...  19.0    male         secondary school
# 28        1.0           2.0     2.0  ...  19.0  female           primary school
# 19        3.0           1.0     3.0  ...  22.0  female           masters degree
# 27        4.0           1.0     1.0  ...  20.0  female         secondary school
# 18        1.0           1.0     5.0  ...  17.0    male         secondary school
# 33        3.0           1.0     3.0  ...  20.0    male         secondary school
# 17        4.0           2.0     4.0  ...  22.0  female         secondary school
# 36        3.0           1.0     3.0  ...  19.0    male         secondary school
# 9         3.0           1.0     2.0  ...  18.0    male  college/bachelor degree
#
# [10 rows x 10 columns]

# %% [markdown]
# > ### **2.2. Find Duplicate Rows in Datasets**

# %%
features.remove('Spend')
dups = df_train[df_train.duplicated(subset=features, keep=False)]
print(dups)
# Out:
#      Lifestyle  Hypochondria  Health  ...  Gender                Education  Spend
# 352        4.0           4.0     4.0  ...  female  college/bachelor degree    4.0
# 353        4.0           4.0     4.0  ...  female  college/bachelor degree    4.0
# 838        1.0           1.0     2.0  ...  female         secondary school    2.0
# 844        1.0           1.0     2.0  ...  female         secondary school    3.0
# 847        2.0           1.0     2.0  ...  female         secondary school    2.0
# 941        2.0           1.0     2.0  ...  female         secondary school    4.0
#
# [6 rows x 11 columns]

# %%
removed_idx = [353, 844, 941]
print(removed_idx)
# Out:
# [353, 844, 941]

# %% [markdown]
# > ### **2.3. Find Outliners in Datasets**

# %%
df_train.boxplot(figsize=(20,15), rot=45)
plt.tick_params(labelsize=14)
plt.ylabel('Count')
plt.xlabel('Selected Features')
plt.title('Numerical Values Distribution in Selected Features in Training Set')
plt.show()

# %%
df_pred_.boxplot(figsize=(20,15), rot=45)
plt.xlabel('Selected Features')
plt.title('Numerical Values Distribution in Selected Features in Prediction Set')
plt.show()

# %%
# over_height defined by Height of anyone > 200cm
over_height = df_train[df_train.Height > 200]
removed_idx.extend(over_height.index.to_list())
print(over_height)

# under_height defined by Height of anyone < 125cm
under_height = df_train[df_train.Height < 125]
removed_idx.extend(under_height.index.to_list())
print(under_height)

# over_weight defined by Weight of anyone > 110kg
over_weight = df_train[df_train.Weight > 110]
removed_idx.extend(over_weight.index.to_list())
print(over_weight)

print('Rows with following indices needs to be removed:')
print(removed_idx)
# Out:
#      Lifestyle  Hypochondria  Health  ...  Gender         Education  Spend
# 523        2.0           1.0     2.0  ...    male  secondary school    4.0
# 764        3.0           2.0     3.0  ...    male  secondary school    4.0
#
# [2 rows x 11 columns]
#      Lifestyle  Hypochondria  Health  ...  Gender                Education  Spend
# 646        4.0           2.0     3.0  ...  female  college/bachelor degree    4.0
#
# [1 rows x 11 columns]
#      Lifestyle  Hypochondria  Health  ...  Gender         Education  Spend
# 283        3.0           1.0     3.0  ...  female  secondary school    4.0
# 683        2.0           1.0     3.0  ...    male  secondary school    2.0
# 758        2.0           3.0     4.0  ...    male  doctorate degree    3.0
# 761        3.0           1.0     4.0  ...    male  doctorate degree    4.0
# 823        3.0           1.0     1.0  ...    male  secondary school    3.0
# 849        2.0           1.0     3.0  ...  female  secondary school    5.0
# 933        1.0           4.0     3.0  ...  female  secondary school    4.0
# 952        1.0           1.0     3.0  ...    male    masters degree    4.0
#
# [8 rows x 11 columns]
# Rows with following indices needs to be removed:
# [353, 844, 941, 523, 764, 646, 283, 683, 758, 761, 823, 849, 933, 952]

# %% [markdown]
# > ### **2.4. Remove Duplicated and Unecessary Outliners in Training Dataset**

# %%
df_train.drop(index=removed_idx, inplace=True)
df_train.reset_index(drop=True, inplace=True)

# %% [markdown]
# > ### **2.5. Find and Fill Missing Values in Datasets**

# %%
df_train.isnull().sum().plot(kind='bar', figsize=(20,8), rot=45)
plt.tick_params(labelsize=14)
plt.ylabel('Count')
plt.xlabel('Selected Features')
plt.title('Missing Values in Selected Features in Training Set')
plt.show()

# %%
df_pred_.isnull().sum().plot(kind='bar', figsize=(20,5), rot=45)
plt.tick_params(labelsize=14)
plt.ylabel('Count')
plt.xlabel('Selected Features')
plt.title('Missing Values in Selected Features in Prediction Set')
plt.show()

# %% [markdown]
# > ### **Fill Each Missing Value with Column Median**

# %%
df_train = df_train.fillna(df_train.median())
df_pred_ = df_pred_.fillna(df_pred_.median())

# %%
df_train.boxplot(figsize=(20,15), rot=45)
plt.tick_params(labelsize=14)
plt.xlabel('Selected Features')
plt.title('Numerical Values Distribution in Selected Features in Training Set')
plt.show()

# %% [markdown]
# > ### **2.6. Feature Selection and Engineering**

# %%
print(df_train.sample(10))
print('\n' + '* ' * 30)
print(df_pred_.sample(10))
print('\n' + '* ' * 30)
print('Datasets selected deatures:', features)
# Out:
#      Lifestyle  Hypochondria  ...                         Education  Spend
# 705        5.0           3.0  ...           college/bachelor degree    5.0
# 301        3.0           1.0  ...           college/bachelor degree    5.0
# 62         4.0           1.0  ...           college/bachelor degree    5.0
# 78         3.0           3.0  ...                  secondary school    3.0
# 451        2.0           3.0  ...                    masters degree    4.0
# 121        3.0           2.0  ...                  secondary school    4.0
# 581        5.0           1.0  ...  currently a primary school pupil    5.0
# 209        3.0           1.0  ...                  secondary school    5.0
# 480        3.0           2.0  ...                    masters degree    5.0
# 806        4.0           2.0  ...                  secondary school    5.0
#
# [10 rows x 11 columns]
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#     Lifestyle  Hypochondria  Health  ...   Age  Gender         Education
# 25        3.0           3.0     5.0  ...  22.0    male  secondary school
# 27        4.0           1.0     1.0  ...  20.0  female  secondary school
# 18        1.0           1.0     5.0  ...  17.0    male  secondary school
# 36        3.0           1.0     3.0  ...  19.0    male  secondary school
# 33        3.0           1.0     3.0  ...  20.0    male  secondary school
# 5         4.0           1.0     3.0  ...  29.0    male  secondary school
# 12        4.0           3.0     3.0  ...  22.0  female  secondary school
# 14        2.0           1.0     2.0  ...  20.0  female    primary school
# 17        4.0           2.0     4.0  ...  22.0  female  secondary school
# 1         3.0           2.0     4.0  ...  20.0  female  secondary school
#
# [10 rows x 10 columns]
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Datasets selected deatures: ['Lifestyle', 'Hypochondria', 'Health', 'Look', 'Height', 'Weight', 'Taste', 'Age', 'Gender', 'Education']

# %%
f_gender = lambda g: 'Male' if g == 'male' else 'Female'
df_train['Gender'] = df_train['Gender'].apply(f_gender)
df_pred_['Gender'] = df_pred_['Gender'].apply(f_gender)

degrees = ['college/bachelor degree', 'masters degree', 'MS', 'doctorate degree']
f_education = lambda e: 'Degree' if e in degrees else 'Non_Degree'
df_train['Education'] = df_train['Education'].apply(f_education)
df_pred_['Education'] = df_pred_['Education'].apply(f_education)

df_train = pd.get_dummies(df_train, drop_first=True, prefix='', prefix_sep='')
df_pred_ = pd.get_dummies(df_pred_, drop_first=True, prefix='', prefix_sep='')

df_train['Taste'] = df_train['Taste'].astype(float)
df_pred_['Taste'] = df_pred_['Taste'].astype(float)

df_train['BMI'] = df_train.Weight / (df_train.Height**2)
df_pred_['BMI'] = df_pred_.Weight / (df_pred_.Height**2)

print(df_train.sample(10))
print('\n' + '* ' * 45)
print(df_train.info())
print('\n' + '* ' * 45)
print(df_pred_.sample(10))
print('\n' + '* ' * 45)
print(df_pred_.info())
# Out:
#      Lifestyle  Hypochondria  Health  Look  ...  Spend  Male  Non_Degree       BMI
# 638        2.0           3.0     3.0   3.0  ...    2.0     1           0  0.002377
# 783        4.0           3.0     4.0   4.0  ...    5.0     0           1  0.001949
# 199        3.0           3.0     3.0   3.0  ...    3.0     1           0  0.002511
# 941        4.0           1.0     3.0   2.0  ...    4.0     0           1  0.001995
# 220        3.0           1.0     3.0   2.0  ...    2.0     0           1  0.002409
# 545        3.0           1.0     2.0   5.0  ...    5.0     1           1  0.002240
# 203        4.0           5.0     5.0   5.0  ...    4.0     1           1  0.002422
# 847        3.0           3.0     3.0   3.0  ...    3.0     1           1  0.002477
# 535        3.0           1.0     1.0   3.0  ...    3.0     1           1  0.002422
# 831        4.0           1.0     4.0   4.0  ...    4.0     1           1  0.002174
#
# [10 rows x 12 columns]
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Lifestyle     956 non-null    float64
#  1   Hypochondria  956 non-null    float64
#  2   Health        956 non-null    float64
#  3   Look          956 non-null    float64
#  4   Height        956 non-null    float64
#  5   Weight        956 non-null    float64
#  6   Taste         956 non-null    float64
#  7   Age           956 non-null    float64
#  8   Spend         956 non-null    float64
#  9   Male          956 non-null    uint8
#  10  Non_Degree    956 non-null    uint8
#  11  BMI           956 non-null    float64
# dtypes: float64(10), uint8(2)
# memory usage: 76.7 KB
# None
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#     Lifestyle  Hypochondria  Health  Look  ...   Age  Male  Non_Degree       BMI
# 23        5.0           1.0     3.0   5.0  ...  21.0     1           1  0.002996
# 18        1.0           1.0     5.0   5.0  ...  17.0     1           1  0.001959
# 17        4.0           2.0     4.0   4.0  ...  22.0     0           1  0.002539
# 20        3.0           1.0     3.0   3.0  ...  19.0     0           1  0.002231
# 39        3.0           2.0     3.0   3.0  ...  27.0     1           0  0.002370
# 11        2.0           3.0     3.0   3.0  ...  19.0     1           1  0.002715
# 10        4.0           1.0     4.0   4.0  ...  22.0     1           0  0.002630
# 31        3.0           4.0     2.0   2.0  ...  22.0     0           0  0.002032
# 4         3.0           1.0     4.0   4.0  ...  23.0     1           1  0.002403
# 34        3.0           1.0     4.0   4.0  ...  21.0     0           1  0.001972
#
# [10 rows x 11 columns]
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Lifestyle     40 non-null     float64
#  1   Hypochondria  40 non-null     float64
#  2   Health        40 non-null     float64
#  3   Look          40 non-null     float64
#  4   Height        40 non-null     float64
#  5   Weight        40 non-null     float64
#  6   Taste         40 non-null     float64
#  7   Age           40 non-null     float64
#  8   Male          40 non-null     uint8
#  9   Non_Degree    40 non-null     uint8
#  10  BMI           40 non-null     float64
# dtypes: float64(9), uint8(2)
# memory usage: 3.0 KB
# None

# %%
(100 * df_train['Spend'].value_counts(dropna=True) / len(df_train['Spend'])).plot(kind='bar', figsize=(20,8))
plt.ylabel('Percent')
plt.xlabel('Class')
plt.title('Distribution of Target')
plt.show()
print(df_train['Spend'].shape)
# Out:
# (956,)

# %%
features = df_pred_.columns.to_list()
sns.pairplot(pd.concat([df_train[features], df_train['Spend']], axis=1), hue='Spend')
plt.show()

# %%
sns.pairplot(df_pred_)
plt.show()

# %% [markdown]
# > ### **2.7. Verify Engineered Features**

# %%
pd.concat([df_train.BMI, df_pred_.BMI], axis=1).boxplot(figsize=(8,8))
plt.ylabel('kg/cm**2')
plt.title('Body Mass Index Distributions in Training and Prediction Sets')
plt.show()

# %% [markdown]
# > ### **2.8. Verify Training, Prediction Dataset and All Features**

# %%
print('Sizes of training and prediction datasets:')
print(df_train.shape, df_pred_.shape)
print('\n' + '* ' * 45)
print('Features of training dataset:')
print(df_train.columns.to_list())
print('\n' + '* ' * 45)
print('Features of prediction dataset:')
print(df_pred_.columns.to_list())
# Out:
# Sizes of training and prediction datasets:
# (956, 12) (40, 11)
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Features of training dataset:
# ['Lifestyle', 'Hypochondria', 'Health', 'Look', 'Height', 'Weight', 'Taste', 'Age', 'Spend', 'Male', 'Non_Degree', 'BMI']
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Features of prediction dataset:
# ['Lifestyle', 'Hypochondria', 'Health', 'Look', 'Height', 'Weight', 'Taste', 'Age', 'Male', 'Non_Degree', 'BMI']

# %% [markdown]
# > ### **2.9. Apply PCA on Datasets**

# %%
from sklearn.decomposition import PCA
n_comps = 4
pca_train = PCA(n_components=n_comps)
pca_train.fit(df_train[features])
print(np.round(pca_train.explained_variance_ratio_ * 100, 0))
df_train_pca = pca_train.transform(df_train[features]) 
print('\n' + '* ' * 20)
pca_pred_ = PCA(n_components=n_comps)
pca_pred_.fit(df_pred_)
print(np.round(pca_pred_.explained_variance_ratio_ * 100, 0))
df_pred__pca = pca_pred_.transform(df_pred_)
# Out:
# [83. 11.  3.  1.]
#
# * * * * * * * * * * * * * * * * * * * *
# [87.  9.  2.  1.]

# %% [markdown]
# # **3. Train and Validate Baseline Models**
# > ### **3.1. Set up Librabries and Helper Functions**

# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier
from sklearn.multiclass import OneVsRestClassifier, OneVsOneClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

def get_models(seed=111):
    models, n_trees = {}, 100
    # Logistic Regression
    models['LGR'] = LogisticRegression()
    # Support Vector Classifier
    models['SVC'] = SVC(gamma='auto')
    # KNearest Neighbors Classifier
    models['KNN'] = KNeighborsClassifier(n_neighbors=3)
    # Bagging Classifier
    models['BAG'] = BaggingClassifier(n_estimators=n_trees, random_state=seed )
    # Random Forest Classifier
    models['RFR'] = RandomForestClassifier(n_estimators=n_trees, random_state=seed)
    # Extra Trees Classifier
    models['ETC'] = ExtraTreesClassifier(n_estimators=n_trees, random_state=seed)
    # Quadratic Discriminant Analysis
    models['QDA'] = QuadraticDiscriminantAnalysis()
    # Neural Network
    models['ANN'] = MLPClassifier()
    return models

# %% [markdown]
# > ### **3.2. Train and Validate Models**

# %%
from sklearn.model_selection import cross_val_score as CVS
from sklearn.model_selection import cross_val_predict as CVP

f = ['Lifestyle', 'Hypochondria', 'Look'] 
y = df_train['Spend'].apply(lambda x: x if x > 2 else 2)
X, y = np.array(df_train[f]), np.array(y)
models, m = get_models(), len(np.unique(y))
model_accuracy, seed = {}, 111

for name, model in models.items():
  acc, cfm = [], np.zeros((m,m))
  kf = KFold(n_splits=5, shuffle=True, random_state=seed)
  acc = CVS(model, X, y, cv=kf, scoring='accuracy')
  y_pred = CVP(model, X, y, cv=kf)
  cfm = confusion_matrix(y, y_pred)
  model_accuracy[name] = acc
  print('Model\tAccuracy (Mean)\tAccuracy (STD)')
  print('{}\t{:.3f}\t\t{:.3f}'.format(name, np.mean(acc), np.std(acc)))
  print('\tConfusion Matrix:')
  print(cfm)
  print('\n' + '* ' * 15)
# Out:
# Model	Accuracy (Mean)	Accuracy (STD)
# LGR	0.364		0.034
# 	Confusion Matrix:
# [[ 31  50  75   9]
#  [ 25  49 170  27]
#  [ 21  39 196  51]
#  [  7  16 118  72]]
#
# * * * * * * * * * * * * * * *
# Model	Accuracy (Mean)	Accuracy (STD)
# SVC	0.413		0.022
# 	Confusion Matrix:
# [[ 43  80  37   5]
#  [ 24 154  83  10]
#  [ 25 118 141  23]
#  [ 10  67  79  57]]
#
# * * * * * * * * * * * * * * *
# Model	Accuracy (Mean)	Accuracy (STD)
# KNN	0.311		0.034
# 	Confusion Matrix:
# [[ 58  60  36  11]
#  [ 76 107  62  26]
#  [ 79 106  80  42]
#  [ 31  64  66  52]]
#
# * * * * * * * * * * * * * * *
# Model	Accuracy (Mean)	Accuracy (STD)
# BAG	0.383		0.020
# 	Confusion Matrix:
# [[ 44  65  46  10]
#  [ 38 119  89  25]
#  [ 34  90 143  40]
#  [ 18  53  82  60]]
#
# * * * * * * * * * * * * * * *
# Model	Accuracy (Mean)	Accuracy (STD)
# RFR	0.386		0.018
# 	Confusion Matrix:
# [[ 44  67  45   9]
#  [ 38 117  91  25]
#  [ 32  92 146  37]
#  [ 16  54  81  62]]
#
# * * * * * * * * * * * * * * *
# Model	Accuracy (Mean)	Accuracy (STD)
# ETC	0.384		0.018
# 	Confusion Matrix:
# [[ 45  73  41   6]
#  [ 46 123  83  19]
#  [ 41  94 143  29]
#  [ 22  57  78  56]]
#
# * * * * * * * * * * * * * * *
# Model	Accuracy (Mean)	Accuracy (STD)
# QDA	0.379		0.019
# 	Confusion Matrix:
# [[ 51  62  47   5]
#  [ 35  90 125  21]
#  [ 29  86 148  44]
#  [ 10  50  80  73]]
#
# * * * * * * * * * * * * * * *
# Model	Accuracy (Mean)	Accuracy (STD)
# ANN	0.401		0.038
# 	Confusion Matrix:
# [[ 46  59  49  11]
#  [ 28  85 122  36]
#  [ 28  62 166  51]
#  [  9  36  94  74]]
#
# * * * * * * * * * * * * * * *

# %% [markdown]
# > ### **3.3. Visualize Accuracy Scores**

# %%
# Plot the accuracy scores
plt.boxplot(list(model_accuracy.values()), 
            labels=list(model_accuracy.keys()), showmeans=True)
plt.grid()
plt.gcf().set_size_inches(12, 8)
plt.show()
